# %% [markdown]
# <a href="https://colab.research.google.com/github/lucimarNeves/usando-plot/blob/main/usandoPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
##Criar figura e eixos ###
fig, ax = plt.subplots()
nomefig = 'teste1.png'
#############################
ax.plot([2,3,4])

## Salvar a figura
fig.savefig(nomefig)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
### estrutura de dados como array
fig, ax = plt.subplots()
nomefig = 'teste2.png'

x = np.array([2,3,4,7,10,11])
ax.plot(x, x**2) ##aparece uma parábola
fig.savefig(nomefig)
plt.show()

# %%
### estrutura de dados como array
fig, ax = plt.subplots()
nomefig = 'teste3.png'

x = np.array([2,2.5, 3, 3.5,4,7,10,11])
x = np.linspace(0, 15, 100)
ax.plot(x, np.sin(x)) ##aparece uma senoide
        
fig.savefig(nomefig)
plt.show()

# %%
### estrutura de dados como array
fig, ax = plt.subplots()
nomefig = 'teste3.png'

x = np.array([2,2.5, 3, 3.5,4,7,10,11])
x = np.linspace(0, 15, 100)
ax.plot(x, np.exp(x)) ##aparece uma exponencial
        
fig.savefig(nomefig)
plt.show()

# %%
### estrutura de dados como array
fig, ax = plt.subplots()
nomefig = 'teste3.png'

x = np.array([2,2.5, 3, 3.5,4,7,10,11])
x = np.linspace(0, 15, 100)
ax.plot(x, x**3) ##aparece x ao cubo
        
fig.savefig(nomefig)
plt.show()

# %%
### estrutura de dados como array
fig, ax = plt.subplots(figsize = (9, 6))
nomefig = 'teste4.png'

##definindo variaveis tamanho da letra
xlab = 'Tempo em relação a quinta-feira 11/08/2021' #nome da label
fsize = 8 #tamanho da letra
##($\eta $C) aparece um eta, ($\int $C) aparece uma integral,  ($^o$C )/($\mathrm{^o}$C) graus Célsios
ylab = 'Temperatura prevista - graus Célsius($\mathrm{^o}$C)' 
fsize, lsize = 22, 10 ##tamanho

####eixo x - Horario ####
horas = np.linspace(0, 3*7, 8)
print(horas)
tempo = ['Qua 14h','Qui 16h','Qui 7h','Sab 4h','Dom 7h','Seg 10h','Ter 13h','Qua 16h']

##Previsão de temperatura ###
####eixo y - temperatura prevista
Temp = np.array([8,7,6,9,13,14,13,12]) 

### Plotar dados ######
ax.plot(tempo, Temp, marker = 'o', lw = 2, ls = '--', ms = 10, color = 'blue') 
#marker bolinha na linha, lw= grossura da linha, ms = tamamnho da bolinha, ls pontilhado

#configurar gráfico
#ax.set_xlabel(xlab, fontsize=fsize) #3setando o label do x
ax.set_ylabel(ylab, fontsize=fsize)
ax.tick_params(axis = 'x', labelsize=lsize, width = 5, labelrotation = 30) ##espaços que tem, só aplicou no x ou y, both é o padrão, width = 15 largura do traço
ax.grid(ls = '--') ##colocando um grid ls -- deixa tracejado as linhas
        
fig.savefig(nomefig)
plt.show()
# Out:
# [ 0.  3.  6.  9. 12. 15. 18. 21.]
